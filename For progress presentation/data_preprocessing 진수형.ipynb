# %%
import pandas as pd

data = pd.read_excel('/Users/jinsoo/Documents/3-2/Business Analytics(화)/TEAM PROJECT/Data/Data_merged6.xlsx')

# %%
data = pd.DataFrame(data)

# %%
data.describe()
# Out:
#               Year   BirthRate  LaborParticipationRate  AvgHoursWorked  \
# count   480.000000  480.000000              480.000000      453.000000
# mean   2005.500000   10.296250               62.495477     1714.458318
# std       9.242726    1.719429                9.149430      165.567786
# min    1990.000000    5.100000               40.350000     1319.131000
# 25%    1997.750000    9.400000               56.317250     1592.659000
# 50%    2005.500000    9.900000               62.416500     1716.341000
# 75%    2013.250000   11.200000               69.820500     1811.852000
# max    2021.000000   16.700000               80.061000     2228.000000
#
#        BothWorking  FirstBirthAge  MarriageAge  MarriageRate  EmploymentRate  \
# count    191.00000     455.000000   174.000000    406.000000      497.000000
# mean      53.27801      29.860879    28.442529      5.116502       53.540694
# std        8.97173       1.456630     2.434869      1.067013        6.399812
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555 entries, 0 to 554
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        480 non-null    object
#  1   Year                      480 non-null    float64
#  2   Country Name              480 non-null    object
#  3   BirthRate                 480 non-null    float64
#  4   LaborParticipationRate    480 non-null    float64
#  5   AvgHoursWorked            453 non-null    float64
#  6   BothWorking               191 non-null    float64
#  7   FirstBirthAge             455 non-null    float64
#  8   MarriageAge               174 non-null    float64
#  9   MarriageRate              406 non-null    float64
#  10  EmploymentRate            497 non-null    float64
#  11  UnemploymentRate          434 non-null    float64
#  12  HousingPrice              414 non-null    float64
# ...

# %% [markdown]
# ## 결측치 비율

# %%
import pandas as pd
missing_ratio = data.isnull().mean() * 100
missing_ratio_df = pd.DataFrame(missing_ratio, columns=['missing_ratio'])
missing_ratio_df.sort_values(by='missing_ratio', ascending=False, inplace=True)
print(missing_ratio_df)
# Out:
#                           missing_ratio
# MarriageAge                   68.648649
# BothWorking                   65.585586
# PovertyGap                    44.504505
# HealthExpenditure             42.702703
# EduExpenditureOfGov           33.333333
# MarriageRate                  26.846847
# HousingPrice                  25.405405
# LaborMarketExpenditure        25.225225
# EduExpenditureOfGDP           25.225225
# InterestRate                  22.162162
# UnemploymentRate              21.801802
# FamilyExpenditure             19.819820
# UnemploymentExpenditure       19.639640
# AvgHoursWorked                18.378378
# FirstBirthAge                 18.018018
# GNI                           18.018018
# GDI                           15.315315
# GDP                           13.693694
# ID                            13.513514
# Year                          13.513514
# LaborParticipationRate        13.513514
# BirthRate                     13.513514
# ...

# %%
columns_to_drop = data.columns[data.isnull().mean() > 0.3]

data = data.drop(columns_to_drop, axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555 entries, 0 to 554
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        480 non-null    object
#  1   Year                      480 non-null    float64
#  2   Country Name              480 non-null    object
#  3   BirthRate                 480 non-null    float64
#  4   LaborParticipationRate    480 non-null    float64
#  5   AvgHoursWorked            453 non-null    float64
#  6   FirstBirthAge             455 non-null    float64
#  7   MarriageRate              406 non-null    float64
#  8   EmploymentRate            497 non-null    float64
#  9   UnemploymentRate          434 non-null    float64
#  10  HousingPrice              414 non-null    float64
#  11  InterestRate              432 non-null    float64
#  12  PartTimeRate              495 non-null    float64
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# # Seaborn 설정
# sns.set(style="whitegrid")

# # 가정: 'Year' 열이 이미 데이터프레임에 포함되어 있어야 합니다.
# # 여기서는 GDP를 예로 들었지만, 다른 피처로 변경할 수 있습니다.

# # 'Country Name'을 기준으로 데이터를 그룹화하여 각 나라별로 그래프를 그립니다.
# g = sns.FacetGrid(data, col="Country Name", col_wrap=1, height=5, aspect=1.5)
# g = g.map(plt.plot, "Year", "GDP", marker=".")

# # 축 이름 설정
# g.set_axis_labels("Year", "GDP")

# # 그래프 타이틀 설정
# g.set_titles("{col_name}")

# # 그래프를 표시합니다.
# plt.show()

# %% [markdown]
# # 결측치 처리 (나라별)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 데이터 로드 (여기서는 'data'가 pandas DataFrame이라고 가정)
# data = pd.read_csv('your_data.csv')

# Seaborn 설정
sns.set(style="whitegrid")

# 'Year' 열이 데이터에 포함되어 있는지 확인
# if 'Year' not in data.columns:
#     # 'Year' 열 추가 필요

# 사용할 피처 리스트 (ID, Country Name, Year 등은 제외)
features = [
    'AvgHoursWorked', 'FirstBirthAge', 'MarriageRate', 'EmploymentRate', 'UnemploymentRate', 'HousingPrice', 'InterestRate', 'PartTimeRate', 'FamilyExpenditure', 'LaborMarketExpenditure', 'UnemploymentExpenditure', 'GDI', 'GDP', 'GNI', 'EduExpenditureOfGDP', 'EduExpenditureOfGov'
]

# 각 피처에 대해 그래프를 그립니다.
for feature in features:
    g = sns.FacetGrid(data, col="Country Name", col_wrap=5, height=3, aspect=1.5)
    g = g.map(plt.plot, "Year", feature, marker=".")

    # 축 이름 설정
    g.set_axis_labels("Year", feature)
    
    # 그래프 타이틀 설정
    g.set_titles("{col_name}")
    
    # 그래프를 표시합니다.
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [51], in <cell line: 21>()
#      21 for feature in features:
#      22     g = sns.FacetGrid(data, col="Country Name", col_wrap=5, height=3, aspect=1.5)
# ---> 23     g = g.map(plt.plot, "Year", feature, marker=".")
#      25     # 축 이름 설정
#      26     g.set_axis_labels("Year", feature)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/axisgrid.py:700, in FacetGrid.map(self, func, *args, **kwargs)
#     697     kwargs["label"] = utils.to_utf8(self.hue_names[hue_k])
#     699 # Get the actual data we are going to plot with
# --> 700 plot_data = data_ijk[list(args)]
#     701 if self._dropna:
#     702     plot_data = plot_data.dropna()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
# ...
